# %% [markdown]
# # Lab | Probability Distributions

# %% [markdown]
# Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# Import your libraries
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom, geom, poisson

# %% [markdown]
# # Challenge 1 - Plot Probability Mass Function (PMF)

# %% [markdown]
# #### Background knowledge
#
# [PMF](https://en.wikipedia.org/wiki/Probability_mass_function) shows the probability distribution of a **discrete random variable**. A [discrete random variable](https://en.wikipedia.org/wiki/Random_variable#Discrete_random_variable) has random numeric values that are not continuous. For example, the number of people in a household can only be integers but not floats. Therefore the number of people in a household is a discrete variable.
#
# #### Question: We assume that the probability of clicking an Ad in a Youtube video is 0.15. We have a sample of 5 people who watched the video and we want to plot the PMF for a binomial distribution.
#
# *Hint: use binom from `scipy.stats.binom`. Your output should look like below:*
#
# ![binom 10](ch-2.png)

# %%
# Your code here

# Parameters
n_people = 5  # number of people
p_success = 0.15  # probability of clicking on Ad

# Possible number of clicks (0 to n_people)
k_values = np.arange(0, n_people + 1)

# Binomial probabilities
probabilities = binom.pmf(k_values, n_people, p_success)

# Plot
plt.bar(k_values, probabilities, color='skyblue', edgecolor='black')
plt.title('Binomial Distribution: Clicks out of 5 People')
plt.xlabel('Number of Clicks')
plt.ylabel('Probability')
plt.xticks(k_values)
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# C:\Users\Friedrich\AppData\Local\Temp\ipykernel_27808\912100668.py:19: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# #### Explain what you observe from the plot above

# %%
# Your comment here
"""
The probability that noone clicks on an Ad is around 45%
The probability that one person clicks is slightly lower at ca. 38%
2 Persons clicking an ad is already very much less likely at around 14% 
3 or more People clicking is very unlikely

"""

# %% [markdown]
# #### Now plot PMP with 50, 500, and 5000 visitors.

# %%
# Your code here

# Parameters
n_people = 50  # number of people
p_success = 0.15  # probability of clicking on Ad

# Possible number of clicks (0 to n_people)
k_values = np.arange(0, n_people + 1)
k_values_500 = np.arange(0, 500+  1)
k_values_1000 = np.arange(0, 1000+  1)

# Binomial probabilities
probabilities = binom.pmf(k_values, n_people, p_success)
probabilities_500 = binom.pmf(k_values_500, 500, p_success)
probabilities_1000 = binom.pmf(k_values_1000, 1000, p_success)

fig, axes = plt.subplots(3, 1, figsize=(15, 15))  # 1 row, 3 columns
# Example: plot the first bar chart on the first axis
axes[0].bar(k_values, probabilities, color='skyblue', edgecolor='black')
axes[0].set_title(f'Binomial Distribution: Clicks out of {n_people} People')
axes[0].set_xlabel('Number of Clicks')
axes[0].set_ylabel('Probability')
axes[0].set_xticks(k_values)
axes[0].legend()
axes[0].grid(axis='y', linestyle='--', alpha=0.7)

axes[1].bar(k_values_500, probabilities_500, color='skyblue', edgecolor='black')
axes[1].set_title(f'Binomial Distribution: Clicks out of 500 People')
axes[1].set_xlabel('Number of Clicks')
axes[1].set_ylabel('Probability')
axes[1].set_xticks(k_values_500)
axes[1].legend()
axes[1].grid(axis='y', linestyle='--', alpha=0.7)

axes[2].bar(k_values_1000, probabilities_1000, color='skyblue', edgecolor='black')
axes[2].set_title(f'Binomial Distribution: Clicks out of 1000 People')
axes[2].set_xlabel('Number of Clicks')
axes[2].set_ylabel('Probability')
axes[2].set_xticks(k_values_1000)
axes[2].legend()
axes[2].grid(axis='y', linestyle='--', alpha=0.7)

axes[0].set_xticks(np.arange(0, n_people+1, 5))      # every 5 clicks
axes[1].set_xticks(np.arange(0, 501, 50))            # every 50 clicks
axes[2].set_xticks(np.arange(0, 1001, 100))          # every 100 clicks
# Out:
# C:\Users\Friedrich\AppData\Local\Temp\ipykernel_27808\2479266665.py:24: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[0].legend()
# C:\Users\Friedrich\AppData\Local\Temp\ipykernel_27808\2479266665.py:32: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[1].legend()
# C:\Users\Friedrich\AppData\Local\Temp\ipykernel_27808\2479266665.py:40: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[2].legend()
# ...

# %% [markdown]
# #### What did you notice from the distribution plots? Comment your findings.

# %%
# Your comment here
"""
The more people that are considered, the higher the amount of likely clicks (but always around 10 to 20% peaking at 15%)
The more people that are considered, the more the distribution resembles a bell courve

"""

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Reaserch the Poisson distribution. Write about your own understanding of the Poisson distribution.

# %%
# Your comment here

Poisson: "In a given time/space, how many random events happen?"

# %% [markdown]
# #### A website has an average of 300 visits per day. What is the probability of getting 320 visitors in a day?
#
# *Hint: use `scipy.stats.poisson`*

# %%
# Your code here
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Parameters for the possion problem
lambda_rate = 300  # average accidents per day

# Poisson distribution: probability of 0 accidents tomorrow
k_target = 320
prob_320 = poisson.pmf(k_target, lambda_rate)
print(f"Probability of {k_target} Visitors in a single Day: {prob_320:.2%}")
# Out:
# Probability of 320 Visitors in a single Day: 1.16%

# %% [markdown]
# #### What is the probability of getting 60 visits?

# %%
# Parameters for the possion problem
lambda_rate = 300  # average accidents per day

# Poisson distribution: probability of 0 accidents tomorrow
k_target = 60
prob_320 = poisson.pmf(k_target, lambda_rate)
print(f"Probability of {k_target} Visitors in a single Day: {prob_320:.2%}")
# Out:
# Probability of 60 Visitors in a single Day: 0.00%

# %% [markdown]
# #### Plot the distribution of the probability for getting 0-1000 visits.
#
# *Hints:*
#
# - Create a list to store the Poisson distribution probabilities for n=0 to 1000. Then plot the probabilities.
#
# - Your plot should look like below:
#
# ![poisson distribution](ch-3.png)

# %%
# Your code here
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Parameters for the possion problem
lambda_rate = 300  # average accidents per day
n_trials = 1000  # number of possible accident counts considered for plotting
# Values for plotting
k_values = np.arange(0, n_trials + 1)

pmf_values = poisson.pmf(k_values, lambda_rate)

# Plot PMF
plt.bar(k_values, pmf_values, color='lightcoral', edgecolor='black', label='PMF')
plt.title('Probability Mass Function (PMF): Visitors per Day')
plt.xlabel('Number of Visitors')
plt.ylabel('Probability')
plt.xticks(k_values)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()
# Reduce x-axis ticks for readability (every 100)
plt.xticks(np.arange(0, n_trials + 1, 100))
plt.show()
